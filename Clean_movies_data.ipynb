# %%
import bs4
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd
import numpy as np
import datetime 
import os

# %%
def convdollar(x):
    
    """
    Converts box-office gross to easily readable string 
    """
    
    billion = 1000000000
    million = 1000000
    
    x = float(x)*100000
    
    if (x >= 1000000000):
    
        y = f"${str(round(x/billion,2))} billion"
    else:
        y = f"${str(round(x/million,2))} million"
        
    return(y)

# %%
def scrape():
    """
    Gets all box office data from 2019 to present from boxofficemojo.com
    """
    years=[str(a) for a in range(2019,2020)]
    df_list=[]
    for year in years:
        r=rq.get('https://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=%s&p=.htm' % year)
        print('Box Office data for %s scraped' % year)
        p=BeautifulSoup(r.text,'html.parser')
            ### Look for the table ### 
        b=p.find_all('table')
        
        ### Usually the fourth table object on page ### 
        tb=b[3].find_all('td')
         ## Each data field is found in a <td> element in the fourth table. Store all data in a list ## 
        data=[]
        for i in tb:
            if i.find('a')!=None:
                data.append(i.find('a').contents[0])
            elif i.find('font')!=None:
                 data.append(i.find('font').contents[0])
            elif i.find('b')!=None:
                data.append(i.find('b').contents[0])
                ### Still a <b> tag left for <font> tags ## 
        data=[a.contents[0] if type(a)!=bs4.element.NavigableString else a for a in data]
        
        ### Strip special characters ### 
        data=[re.sub('[^A-Za-z0-9-. ]+', '', a) for a in data]
        
        ### Fill NaNs ### 
        data=[np.nan if a =='na' else a for a in data]
        
        ### Define the feature names ###
        columns=['bo_year_rank','title','studio','worldwide-gross','domestic-gross','domestic-pct','overseas-gross','overseas-pct']
        
        ### First 6 elements are column headers # 
        to_df=data[6:]
        
        ### Escape clause in case the layout changes from year to year ### 
        if len(to_df)%len(columns) != 0:
            print('Possible table misalignment in table for year %s' % year)
            break
            
            ### Convert to pandas dataframe ### 
        
        nrow=int(len(to_df)/len(columns))
        df=pd.DataFrame(np.array(to_df).reshape(nrow,8),columns=columns)
        df[['worldwide-gross','domestic-gross','overseas-gross']]=df[['worldwide-gross','domestic-gross','overseas-gross']].apply(convdollar)
        df['bo_year']=int(year)
        df_list.append(df)

        main=pd.concat(df_list)
    
        # Store data into csv # 
        #main.to_csv(os.path.join("output","current_boxoffice_mojo.csv"))
        return (main)
        print (main)

# %%
if __name__ == "__main__": 

    dirtymovies_df=scrape()
# Out:
# Box Office data for 2019 scraped
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-28c2d7ab02a8> in <module>
#       1 if __name__ == "__main__":
#       2
# ----> 3     dirtymovies_df=scrape()
#
# <ipython-input-9-d7535710c86b> in scrape()
#      47         nrow=int(len(to_df)/len(columns))
#      48         df=pd.DataFrame(np.array(to_df).reshape(nrow,8),columns=columns)
# ---> 49         df[['worldwide-gross','domestic-gross','overseas-gross']]=df[['worldwide-gross','domestic-gross','overseas-gross']].apply(convdollar)
#      50         df['bo_year']=int(year)
#      51         df_list.append(df)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-8-d014ffab3b63> in convdollar(x)
#       8     million = 1000000
#       9
# ---> 10     x = float(x)*100000
#      11
#      12     if (x >= 1000000000):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: ("cannot convert the series to <class 'float'>", 'occurred at index worldwide-gross')

# %%
 dirtymovies_df
# Out:
#    bo_year_rank                                              title  \
# 0             1                                   Avengers Endgame
# 1             2                                    Captain Marvel
# 2             3                                The Wandering Earth
# 3             4          How to Train Your Dragon The Hidden World
# 4             5                                 Alita Battle Angel
# 5             6                                             Shazam
# 6             7                                         Dumbo 2019
# 7             8                                                 Us
# 8             9                                              Glass
# 9            10                   The LEGO Movie 2 The Second Part
# 10           11                                        Escape Room
# 11           12                                         The Upside
# 12           13                                        Extreme Job
# 13           14                            Dragon Ball Super Broly
# 14           15                                        Wonder Park
# 15           16                                  Pet Sematary 2019
# 16           17                           The Curse of La Llorona
# 17           18                                    A Dogs Way Home
# 18           19                Tyler Perrys A Madea Family Funeral
# 19           20                                    Five Feet Apart
# 20           21                                      What Men Want
# 21           22                                 Happy Death Day 2U
# 22           23                                       Cold Pursuit
# 23           24                                         After 2019
# 24           25                                             Little
# 25           26                            Fighting with My Family
# 26           27                                       Breakthrough
# 27           28                          The Kid Who Would be King
# 28           29                             Mia and the White Lion
# 29           30                                     Total Dhamaal
# ..          ...                                                ...
# 58           59                     The Man Who Killed Don Quixote
# 59           60                                            P Storm
# 60           61                                            Junglee
# 61           62                        I Want to Eat Your Pancreas
# 62           63                    Mobile Suit Gundam NT Narrative
# 63           64                                 Romeo Akbar Walter
# 64           65                                           Red Joan
# 65           66                             Master Z Ip Man Legacy
# 66           67       Monty Pythons Life of Brian 40th Anniversary
# 67           68                                           Peterloo
# 68           69                                          Okkos Inn
# 69           70                                        Sunset 2019
# 70           71                             Ruben Brandt Collector
# 71           72               Belle and Sebastian Friends for Life
# 72           73                                     The Image Book
# 73           74                                       The Crossing
# 74           75                                         Sonchiriya
# 75           76                                      The Heiresses
# 76           77                                          Storm Boy
# 77           78                                               Styx
# 78           79                                            3 Faces
# 79           80                                         Ramen Shop
# 80           81                              He Matado a mi Marido
# 81           82                                          The Sower
# 82           83                                 The Wild Pear Tree
# 83           84                             The Hole in the Ground
# 84           85                                       Touch Me Not
# 85           86                                     Ferrante Fever
# 86           87                                            Patrick
# 87           88  Tall Tales from the Magical Garden of Antoon K...
#
#          studio  worldwide-gross  domestic-gross domestic-pct  overseas-gross  \
# 0            BV     1.342700e+09     394000000.0         29.3     948700000.0
# 1            BV     1.111400e+09     414500000.0         37.3     696800000.0
# 2           CMC     6.998000e+08       5900000.0          0.8     693900000.0
# 3          Uni.     5.164000e+08     159700000.0         30.9     356700000.0
# 4           Fox     4.044000e+08      85700000.0         21.2     318700000.0
# 5         WB NL     3.462000e+08     131500000.0         38.0     214700000.0
# 6            BV     3.287000e+08     107500000.0         32.7     221200000.0
# 7          Uni.     2.496000e+08     173000000.0         69.3      76600000.0
# 8          Uni.     2.470000e+08     111000000.0         45.0     135900000.0
# 9            WB     1.905000e+08     105700000.0         55.5      84800000.0
# 10         Sony     1.549000e+08      57000000.0         36.8      97900000.0
# 11          STX     1.221000e+08     108200000.0         88.6      13900000.0
# 12           CJ     1.199000e+08       1600000.0          1.3     118400000.0
# 13          FUN     1.108000e+08      30700000.0         27.7      80100000.0
# 14         Par.     1.031000e+08      45000000.0         43.7      58100000.0
# 15         Par.     1.025000e+08      52800000.0         51.5      49700000.0
# 16        WB NL     8.800000e+07      42500000.0         48.3      45500000.0
# 17         Sony     7.570000e+07      42000000.0         55.5      33700000.0
# 18          LGF     7.450000e+07      73100000.0         98.1       1500000.0
# 19          LGF     7.340000e+07      45400000.0         61.9      28000000.0
# 20         Par.     7.210000e+07      54600000.0         75.8      17500000.0
# 21         Uni.     6.420000e+07      28100000.0         43.7      36200000.0
# 22          LGS     5.920000e+07      32100000.0         54.3      27100000.0
# 23       Aviron     4.920000e+07      11700000.0         23.8      37500000.0
# 24         Uni.     4.270000e+07      36100000.0         84.6       6600000.0
# 25          MGM     3.850000e+07      22900000.0         59.5      15600000.0
# 26          Fox     3.550000e+07      27200000.0         76.4       8400000.0
# 27          Fox     3.170000e+07      16800000.0         53.0      14900000.0
# 28    Ledafilms     2.680000e+07        390000.0          1.5      26400000.0
# 29          FIP     2.500000e+07       2200000.0          8.7      22900000.0
# ..          ...              ...             ...          ...             ...
# 58       Fathom     3.280000e+05        328000.0        100.0             NaN
# 59          CMC     3.090000e+05        309000.0        100.0             NaN
# 60          VPD     2.960000e+05        296000.0        100.0             NaN
# 61       Fathom     2.770000e+05        277000.0        100.0             NaN
# 62       Fathom     2.590000e+05        259000.0        100.0             NaN
# 63         Eros     2.360000e+05        236000.0        100.0             NaN
# 64          IFC     2.290000e+05        229000.0        100.0             NaN
# 65        WGUSA     1.890000e+05        189000.0        100.0             NaN
# 66    Trafalgar     1.580000e+05        158000.0        100.0             NaN
# 67       Amazon     1.460000e+05        146000.0        100.0             NaN
# 68           GK     1.250000e+05        125000.0        100.0             NaN
# 69          SPC     1.190000e+05        119000.0        100.0             NaN
# 70          SPC     1.150000e+05        115000.0        100.0             NaN
# 71         EOne     1.060000e+05        106000.0        100.0             NaN
# 72           KL     9.420000e+04         94200.0        100.0             NaN
# 73          CMC     9.090000e+04         90900.0        100.0             NaN
# 74  PackYourBag     8.680000e+04         86800.0        100.0             NaN
# 75     Distrib.     7.250000e+04         72500.0        100.0             NaN
# 76    Good Deed     7.180000e+04         71800.0        100.0             NaN
# 77           FM     6.790000e+04         67900.0        100.0             NaN
# 78           KL     6.620000e+04         66200.0        100.0             NaN
# 79       Strand     5.430000e+04         54300.0        100.0             NaN
# 80          Ham     3.520000e+04         31400.0         89.3          3800.0
# 81           FM     3.410000e+04         34100.0        100.0             NaN
# 82         CGld     3.160000e+04         31600.0        100.0             NaN
# 83          A24     2.110000e+04         21100.0        100.0             NaN
# 84           KL     1.380000e+04         13800.0        100.0             NaN
# 85    Greenwich     1.110000e+04         11100.0        100.0             NaN
# 86        INDEP     6.300000e+03          6300.0        100.0             NaN
# 87          VPD     2.000000e+02           200.0        100.0             NaN
#
#    overseas-pct  bo_year
# 0          70.7     2019
# 1          62.7     2019
# 2          99.2     2019
# 3          69.1     2019
# 4          78.8     2019
# 5          62.0     2019
# 6          67.3     2019
# 7          30.7     2019
# 8          55.0     2019
# 9          44.5     2019
# 10         63.2     2019
# 11         11.4     2019
# 12         98.7     2019
# 13         72.3     2019
# 14         56.3     2019
# 15         48.5     2019
# 16         51.7     2019
# 17         44.5     2019
# 18          1.9     2019
# 19         38.1     2019
# 20         24.2     2019
# 21         56.3     2019
# 22         45.7     2019
# 23         76.2     2019
# 24         15.4     2019
# 25         40.5     2019
# 26         23.6     2019
# 27         47.0     2019
# 28         98.5     2019
# 29         91.3     2019
# ..          ...      ...
# 58          0.0     2019
# 59          0.0     2019
# 60          0.0     2019
# 61          0.0     2019
# 62          0.0     2019
# 63          0.0     2019
# 64          0.0     2019
# 65          0.0     2019
# 66          0.0     2019
# 67          0.0     2019
# 68          0.0     2019
# 69          0.0     2019
# 70          0.0     2019
# 71          0.0     2019
# 72          0.0     2019
# 73          0.0     2019
# 74          0.0     2019
# 75          0.0     2019
# 76          0.0     2019
# 77          0.0     2019
# 78          0.0     2019
# 79          0.0     2019
# 80         10.7     2019
# 81          0.0     2019
# 82          0.0     2019
# 83          0.0     2019
# 84          0.0     2019
# 85          0.0     2019
# 86          0.0     2019
# 87          0.0     2019
#
# [88 rows x 9 columns]

# %%
## Cleaning data by dropping the unessery rows (10-87) drops the bottom 78 trows
dirtymovies_df[:-78]
# Out:
#   bo_year_rank                                      title studio  \
# 0            1                           Avengers Endgame     BV
# 1            2                            Captain Marvel      BV
# 2            3                        The Wandering Earth    CMC
# 3            4  How to Train Your Dragon The Hidden World   Uni.
# 4            5                         Alita Battle Angel    Fox
# 5            6                                     Shazam  WB NL
# 6            7                                 Dumbo 2019     BV
# 7            8                                         Us   Uni.
# 8            9                                      Glass   Uni.
# 9           10           The LEGO Movie 2 The Second Part     WB
#
#    worldwide-gross  domestic-gross domestic-pct  overseas-gross overseas-pct  \
# 0     1.342700e+09     394000000.0         29.3     948700000.0         70.7
# 1     1.111400e+09     414500000.0         37.3     696800000.0         62.7
# 2     6.998000e+08       5900000.0          0.8     693900000.0         99.2
# 3     5.164000e+08     159700000.0         30.9     356700000.0         69.1
# 4     4.044000e+08      85700000.0         21.2     318700000.0         78.8
# 5     3.462000e+08     131500000.0         38.0     214700000.0         62.0
# 6     3.287000e+08     107500000.0         32.7     221200000.0         67.3
# 7     2.496000e+08     173000000.0         69.3      76600000.0         30.7
# 8     2.470000e+08     111000000.0         45.0     135900000.0         55.0
# 9     1.905000e+08     105700000.0         55.5      84800000.0         44.5
#
#    bo_year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# 5     2019
# 6     2019
# 7     2019
# 8     2019
# 9     2019

# %%
#create new dataframe for top 10 
toptenmovies_df = dirtymovies_df[:-78]

# %%
toptenmovies_df
# Out:
#   bo_year_rank                                      title studio  \
# 0            1                           Avengers Endgame     BV
# 1            2                            Captain Marvel      BV
# 2            3                        The Wandering Earth    CMC
# 3            4  How to Train Your Dragon The Hidden World   Uni.
# 4            5                         Alita Battle Angel    Fox
# 5            6                                     Shazam  WB NL
# 6            7                                 Dumbo 2019     BV
# 7            8                                         Us   Uni.
# 8            9                                      Glass   Uni.
# 9           10           The LEGO Movie 2 The Second Part     WB
#
#    worldwide-gross  domestic-gross domestic-pct  overseas-gross overseas-pct  \
# 0     1.342700e+09     394000000.0         29.3     948700000.0         70.7
# 1     1.111400e+09     414500000.0         37.3     696800000.0         62.7
# 2     6.998000e+08       5900000.0          0.8     693900000.0         99.2
# 3     5.164000e+08     159700000.0         30.9     356700000.0         69.1
# 4     4.044000e+08      85700000.0         21.2     318700000.0         78.8
# 5     3.462000e+08     131500000.0         38.0     214700000.0         62.0
# 6     3.287000e+08     107500000.0         32.7     221200000.0         67.3
# 7     2.496000e+08     173000000.0         69.3      76600000.0         30.7
# 8     2.470000e+08     111000000.0         45.0     135900000.0         55.0
# 9     1.905000e+08     105700000.0         55.5      84800000.0         44.5
#
#    bo_year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# 5     2019
# 6     2019
# 7     2019
# 8     2019
# 9     2019

# %%
##clean new dataframe for top 10 by removing rows domestic-pct, overseas-pct
toptenmovies_df.drop("domestic-pct", axis=1).drop("overseas-pct", axis=1)
# Out:
#   bo_year_rank                                      title studio  \
# 0            1                           Avengers Endgame     BV
# 1            2                            Captain Marvel      BV
# 2            3                        The Wandering Earth    CMC
# 3            4  How to Train Your Dragon The Hidden World   Uni.
# 4            5                         Alita Battle Angel    Fox
# 5            6                                     Shazam  WB NL
# 6            7                                 Dumbo 2019     BV
# 7            8                                         Us   Uni.
# 8            9                                      Glass   Uni.
# 9           10           The LEGO Movie 2 The Second Part     WB
#
#    worldwide-gross  domestic-gross  overseas-gross  bo_year
# 0     1.342700e+09     394000000.0     948700000.0     2019
# 1     1.111400e+09     414500000.0     696800000.0     2019
# 2     6.998000e+08       5900000.0     693900000.0     2019
# 3     5.164000e+08     159700000.0     356700000.0     2019
# 4     4.044000e+08      85700000.0     318700000.0     2019
# 5     3.462000e+08     131500000.0     214700000.0     2019
# 6     3.287000e+08     107500000.0     221200000.0     2019
# 7     2.496000e+08     173000000.0      76600000.0     2019
# 8     2.470000e+08     111000000.0     135900000.0     2019
# 9     1.905000e+08     105700000.0      84800000.0     2019

# %%
Cleanedtoptenmovies_df= toptenmovies_df.drop("domestic-pct", axis=1).drop("overseas-pct", axis=1)

# %%
Cleanedtoptenmovies_df
# Out:
#   bo_year_rank                                      title studio  \
# 0            1                           Avengers Endgame     BV
# 1            2                            Captain Marvel      BV
# 2            3                        The Wandering Earth    CMC
# 3            4  How to Train Your Dragon The Hidden World   Uni.
# 4            5                         Alita Battle Angel    Fox
# 5            6                                     Shazam  WB NL
# 6            7                                 Dumbo 2019     BV
# 7            8                                         Us   Uni.
# 8            9                                      Glass   Uni.
# 9           10           The LEGO Movie 2 The Second Part     WB
#
#    worldwide-gross  domestic-gross  overseas-gross  bo_year
# 0     1.342700e+09     394000000.0     948700000.0     2019
# 1     1.111400e+09     414500000.0     696800000.0     2019
# 2     6.998000e+08       5900000.0     693900000.0     2019
# 3     5.164000e+08     159700000.0     356700000.0     2019
# 4     4.044000e+08      85700000.0     318700000.0     2019
# 5     3.462000e+08     131500000.0     214700000.0     2019
# 6     3.287000e+08     107500000.0     221200000.0     2019
# 7     2.496000e+08     173000000.0      76600000.0     2019
# 8     2.470000e+08     111000000.0     135900000.0     2019
# 9     1.905000e+08     105700000.0      84800000.0     2019

# %% [markdown]
#   if x is >= 1000000000 then convert to "1.xx billion"  to make more readable we are going from float to string
#   else convert to xxxmillion
#
#   Next steps for arjun figure out function above then put finished dataframe into mongodbcollection
