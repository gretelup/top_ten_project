# %%
import bs4
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd
import numpy as np
import datetime 
import os

# %%
years=[str(a) for a in range(2008,2019)]
df_list=[]
for year in years:
    r=rq.get('https://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=%s&p=.htm' % year)
    print('Box Office data for %s scraped' % year)
    p=BeautifulSoup(r.text,'html.parser')

    ### Look for the table ### 
    b=p.find_all('table')

    ### Usually the fourth table object on page ### 
    tb=b[3].find_all('td')

    ## Each data field is found in a <td> element in the fourth table. Store all data in a list ## 
    data=[]
    for i in tb:
        if i.find('a')!=None:
            data.append(i.find('a').contents[0])
        elif i.find('font')!=None:
             data.append(i.find('font').contents[0])
        elif i.find('b')!=None:
            data.append(i.find('b').contents[0])

    ### Still a <b> tag left for <font> tags ## 
    data=[a.contents[0] if type(a)!=bs4.element.NavigableString else a for a in data]

    ### Strip special characters ### 
    data=[re.sub('[^A-Za-z0-9-. ]+', '', a) for a in data]

    ### Fill NaNs ### 
    data=[np.nan if a =='na' else a for a in data]

    ### Define the feature names ###
    columns=['bo_year_rank','title','studio','worldwide-gross','domestic-gross','domestic-pct','overseas-gross','overseas-pct']

    ### First 6 elements are column headers # 
    to_df=data[6:]

    ### Escape clause in case the layout changes from year to year ### 
    if len(to_df)%len(columns) != 0:
        print('Possible table misalignment in table for year %s' % year)
        break 

    ### Convert to pandas dataframe ### 

    nrow=int(len(to_df)/len(columns))
    df=pd.DataFrame(np.array(to_df).reshape(nrow,8),columns=columns)
    df['bo_year']=int(year)
    df_list.append(df)

dirtymovies_df=pd.concat(df_list)
# Out:
# Box Office data for 2008 scraped
# Box Office data for 2009 scraped
# Box Office data for 2010 scraped
# Box Office data for 2011 scraped
# Box Office data for 2012 scraped
# Box Office data for 2013 scraped
# Box Office data for 2014 scraped
# Box Office data for 2015 scraped
# Box Office data for 2016 scraped
# Box Office data for 2017 scraped
# Box Office data for 2018 scraped

# %%
dirtymovies_df
# Out:
#     bo_year_rank                                              title  \
# 0              1                                    The Dark Knight
# 1              2  Indiana Jones and the Kingdom of the Crystal S...
# 2              3                                      Kung Fu Panda
# 3              4                                            Hancock
# 4              5                                          Mamma Mia
# 5              6                         Madagascar Escape 2 Africa
# 6              7                                  Quantum of Solace
# 7              8                                           Iron Man
# 8              9                                             WALL-E
# 9             10            The Chronicles of Narnia Prince Caspian
# 10            11                                   Sex and the City
# 11            12               The Mummy Tomb of the Dragon Emperor
# 12            13                                           Twilight
# 13            14                                Slumdog Millionaire
# 14            15                                             Wanted
# 15            16                The Curious Case of Benjamin Button
# 16            17                                               Bolt
# 17            18                       Dr. Seuss Horton Hears a Who
# 18            19                                        Gran Torino
# 19            20                                         10000 B.C.
# 20            21                                The Incredible Hulk
# 21            22                  High School Musical 3 Senior Year
# 22            23                                      Marley and Me
# 23            24                 Journey to the Center of the Earth
# 24            25                 The Day the Earth Stood Still 2008
# 25            26                                          Get Smart
# 26            27                                            Yes Man
# 27            28                                             Jumper
# 28            29                              What Happens in Vegas
# 29            30                                    Bedtime Stories
# ..           ...                                                ...
# 276          277                                   I Am Not a Witch
# 277          278                                Racer  the Jailbird
# 278          279                                              Rodin
# 279          280                               What Will People Say
# 280          281                                          A Ciambra
# 281          282                                   Oolong Courtyard
# 282          283                                 Girls vs Gangsters
# 283          284                               No Date No Signature
# 284          285                                The Apparition 2018
# 285          286                                        The Charmer
# 286          287                       Elliot The Littlest Reindeer
# 287          288                                       The Workshop
# 288          289                                       Loving Pablo
# 289          290                                  A Paris Education
# 290          291                           Tag Along The Devil Fish
# 291          292                           Gabriel and the Mountain
# 292          293                  Marlina the Murderer in Four Acts
# 293          294                                         The Escape
# 294          295  How Victor The Garlic Took Alexey The Stud to ...
# 295          296          Lou Andreas-Salom the Audacity to be Free
# 296          297                                    Let Yourself Go
# 297          298                                        Hannah 2018
# 298          299                                           Souvenir
# 299          300                         Furious Legend of Kolovrat
# 300          301                                Beauty and the Dogs
# 301          302                                          The Quake
# 302          303                          Edward II 2018 re-release
# 303          304                                           El Pacto
# 304          305                                           The Swan
# 305          306                                  An Actor Prepares
#
#          studio worldwide-gross domestic-gross domestic-pct overseas-gross  \
# 0            WB          1003.0          533.3         53.2          469.7
# 1          Par.           786.6          317.1         40.3          469.5
# 2           PDW           631.7          215.4         34.1          416.3
# 3          Sony           624.4          227.9         36.5          396.4
# 4          Uni.           609.8          144.1         23.6          465.7
# 5           PDW           603.9          180.0         29.8          423.9
# 6          Sony           586.1          168.4         28.7          417.7
# 7          Par.           585.2          318.4         54.4          266.8
# 8            BV           533.3          223.8         42.0          309.5
# 9            BV           419.7          141.6         33.7          278.0
# 10        WB NL           415.3          152.6         36.8          262.6
# 11         Uni.           401.1          102.5         25.6          298.6
# 12         Sum.           393.6          192.8         49.0          200.8
# 13         FoxS           377.9          141.3         37.4          236.6
# 14         Uni.           341.4          134.5         39.4          206.9
# 15         Par.           333.9          127.5         38.2          206.4
# 16           BV           310.0          114.1         36.8          195.9
# 17          Fox           297.1          154.5         52.0          142.6
# 18           WB           270.0          148.1         54.9          121.9
# 19           WB           269.8           94.8         35.1          175.0
# 20         Uni.           263.4          134.8         51.2          128.6
# 21           BV           252.9           90.6         35.8          162.3
# 22          Fox           242.7          143.2         59.0           99.6
# 23        WB NL           242.0          101.7         42.0          140.3
# 24          Fox           233.1           79.4         34.0          153.7
# 25           WB           230.7          130.3         56.5          100.4
# 26           WB           223.2           97.7         43.8          125.6
# 27          Fox           222.2           80.2         36.1          142.1
# 28          Fox           219.4           80.3         36.6          139.1
# 29           BV           212.9          110.1         51.7          102.8
# ..          ...             ...            ...          ...            ...
# 276          FM           50.9k          50.9k        100.0            nan
# 277       Super           46.3k          46.3k        100.0            nan
# 278       Cohen           44.3k          44.3k        100.0            nan
# 279          KL           44.2k          44.2k        100.0            nan
# 280         IFC           41.9k          41.9k        100.0            nan
# 281          CL           37.7k          37.7k        100.0            nan
# 282       WGUSA           37.1k          37.1k        100.0            nan
# 283    Distrib.           36.4k          36.4k        100.0            nan
# 284        MBox           28.3k          28.3k        100.0            nan
# 285          FM           26.2k          26.2k        100.0            nan
# 286       Scre.           24.3k          24.3k        100.0            nan
# 287      Strand           22.1k          22.1k        100.0            nan
# 288        Uni.           22.0k          22.0k        100.0            nan
# 289          KL           21.6k          21.6k        100.0            nan
# 290          CL           20.7k          20.7k        100.0            nan
# 291      Strand           18.4k          18.4k        100.0            nan
# 292       Icar.           17.8k          17.8k        100.0            nan
# 293         IFC           14.0k          14.0k        100.0            nan
# 294     CARUSEL           13.0k          13.0k        100.0            nan
# 295         CLS           12.9k          12.9k        100.0            nan
# 296        Men.           12.2k          12.2k        100.0            nan
# 297         PDF           11.7k          11.7k        100.0            nan
# 298      Strand           11.4k          11.4k        100.0            nan
# 299     CARUSEL           10.0k          10.0k        100.0            nan
# 300       Osci.            8.9k           8.9k        100.0            nan
# 301       Magn.            6.2k           6.2k        100.0            nan
# 302          FM            4.8k           4.8k        100.0            nan
# 303        Sony            2.5k           2.5k        100.0            nan
# 304  Synergetic            2.4k           2.4k        100.0            nan
# 305       Grav.            1.7k           1.7k        100.0            nan
#
#     overseas-pct  bo_year
# 0           46.8     2008
# 1           59.7     2008
# 2           65.9     2008
# 3           63.5     2008
# 4           76.4     2008
# 5           70.2     2008
# 6           71.3     2008
# 7           45.6     2008
# 8           58.0     2008
# 9           66.3     2008
# 10          63.2     2008
# 11          74.4     2008
# 12          51.0     2008
# 13          62.6     2008
# 14          60.6     2008
# 15          61.8     2008
# 16          63.2     2008
# 17          48.0     2008
# 18          45.1     2008
# 19          64.9     2008
# 20          48.8     2008
# 21          64.2     2008
# 22          41.0     2008
# 23          58.0     2008
# 24          66.0     2008
# 25          43.5     2008
# 26          56.2     2008
# 27          63.9     2008
# 28          63.4     2008
# 29          48.3     2008
# ..           ...      ...
# 276          0.0     2018
# 277          0.0     2018
# 278          0.0     2018
# 279          0.0     2018
# 280          0.0     2018
# 281          0.0     2018
# 282          0.0     2018
# 283          0.0     2018
# 284          0.0     2018
# 285          0.0     2018
# 286          0.0     2018
# 287          0.0     2018
# 288          0.0     2018
# 289          0.0     2018
# 290          0.0     2018
# 291          0.0     2018
# 292          0.0     2018
# 293          0.0     2018
# 294          0.0     2018
# 295          0.0     2018
# 296          0.0     2018
# 297          0.0     2018
# 298          0.0     2018
# 299          0.0     2018
# 300          0.0     2018
# 301          0.0     2018
# 302          0.0     2018
# 303          0.0     2018
# 304          0.0     2018
# 305          0.0     2018
#
# [4168 rows x 9 columns]

# %%
dirtymovies_df = dirtymovies_df.iloc[: , [0, 1, 2, 8]]
dirtymovies_df["bo_year_rank"] = dirtymovies_df["bo_year_rank"].apply(int)
movies_df = dirtymovies_df.loc[dirtymovies_df["bo_year_rank"] <=10,:]

# %%
movies_df
# Out:
#     bo_year_rank                                              title studio  \
# 0              1                                    The Dark Knight     WB
# 1              2  Indiana Jones and the Kingdom of the Crystal S...   Par.
# 2              3                                      Kung Fu Panda    PDW
# 3              4                                            Hancock   Sony
# 4              5                                          Mamma Mia   Uni.
# 5              6                         Madagascar Escape 2 Africa    PDW
# 6              7                                  Quantum of Solace   Sony
# 7              8                                           Iron Man   Par.
# 8              9                                             WALL-E     BV
# 9             10            The Chronicles of Narnia Prince Caspian     BV
# 0              1                                             Avatar    Fox
# 1              2             Harry Potter and the Half-Blood Prince     WB
# 2              3                      Ice Age Dawn of the Dinosaurs    Fox
# 3              4                 Transformers Revenge of the Fallen    PDW
# 4              5                                               2012   Sony
# 5              6                                                 Up     BV
# 6              7                         The Twilight Saga New Moon   Sum.
# 7              8                                    Sherlock Holmes     WB
# 8              9                                     Angels  Demons   Sony
# 9             10                                       The Hangover     WB
# 0              1                                        Toy Story 3     BV
# 1              2                           Alice in Wonderland 2010     BV
# 2              3        Harry Potter and the Deathly Hallows Part 1     WB
# 3              4                                          Inception     WB
# 4              5                                Shrek Forever After    PDW
# 5              6                          The Twilight Saga Eclipse   Sum.
# 6              7                                         Iron Man 2   Par.
# 7              8                                            Tangled     BV
# 8              9                                      Despicable Me   Uni.
# 9             10                           How to Train Your Dragon    PDW
# ..           ...                                                ...    ...
# 0              1                          Captain America Civil War     BV
# 1              2                        Rogue One A Star Wars Story     BV
# 2              3                                       Finding Dory     BV
# 3              4                                           Zootopia     BV
# 4              5                               The Jungle Book 2016     BV
# 5              6                            The Secret Life of Pets   Uni.
# 6              7                  Batman v Superman Dawn of Justice     WB
# 7              8            Fantastic Beasts and Where To Find Them     WB
# 8              9                                           Deadpool    Fox
# 9             10                                      Suicide Squad     WB
# 0              1                            Star Wars The Last Jedi     BV
# 1              2                          Beauty and the Beast 2017     BV
# 2              3                            The Fate of the Furious   Uni.
# 3              4                                    Despicable Me 3   Uni.
# 4              5                      Jumanji Welcome to the Jungle   Sony
# 5              6                              Spider-Man Homecoming   Sony
# 6              7                                     Wolf Warrior 2     HC
# 7              8                     Guardians of the Galaxy Vol. 2     BV
# 8              9                                      Thor Ragnarok     BV
# 9             10                                       Wonder Woman     WB
# 0              1                              Avengers Infinity War     BV
# 1              2                                      Black Panther     BV
# 2              3                      Jurassic World Fallen Kingdom   Uni.
# 3              4                                      Incredibles 2     BV
# 4              5                                            Aquaman     WB
# 5              6                                  Bohemian Rhapsody    Fox
# 6              7                                         Venom 2018   Sony
# 7              8                       Mission Impossible - Fallout   Par.
# 8              9                                         Deadpool 2    Fox
# 9             10         Fantastic Beasts The Crimes of Grindelwald     WB
#
#     bo_year
# 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
# 5      2008
# 6      2008
# 7      2008
# 8      2008
# 9      2008
# 0      2009
# 1      2009
# 2      2009
# 3      2009
# 4      2009
# 5      2009
# 6      2009
# 7      2009
# 8      2009
# 9      2009
# 0      2010
# 1      2010
# 2      2010
# 3      2010
# 4      2010
# 5      2010
# 6      2010
# 7      2010
# 8      2010
# 9      2010
# ..      ...
# 0      2016
# 1      2016
# 2      2016
# 3      2016
# 4      2016
# 5      2016
# 6      2016
# 7      2016
# 8      2016
# 9      2016
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
# 5      2017
# 6      2017
# 7      2017
# 8      2017
# 9      2017
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
# 5      2018
# 6      2018
# 7      2018
# 8      2018
# 9      2018
#
# [110 rows x 4 columns]

# %%
Moviedictionary = movies_df.to_dict(orient='records')

# %%
print(Moviedictionary)
# Out:
# [{'bo_year_rank': 1, 'title': 'The Dark Knight', 'studio': 'WB', 'bo_year': 2008}, {'bo_year_rank': 2, 'title': 'Indiana Jones and the Kingdom of the Crystal Skull', 'studio': 'Par.', 'bo_year': 2008}, {'bo_year_rank': 3, 'title': 'Kung Fu Panda', 'studio': 'PDW', 'bo_year': 2008}, {'bo_year_rank': 4, 'title': 'Hancock', 'studio': 'Sony', 'bo_year': 2008}, {'bo_year_rank': 5, 'title': 'Mamma Mia', 'studio': 'Uni.', 'bo_year': 2008}, {'bo_year_rank': 6, 'title': 'Madagascar Escape 2 Africa', 'studio': 'PDW', 'bo_year': 2008}, {'bo_year_rank': 7, 'title': 'Quantum of Solace', 'studio': 'Sony', 'bo_year': 2008}, {'bo_year_rank': 8, 'title': 'Iron Man', 'studio': 'Par.', 'bo_year': 2008}, {'bo_year_rank': 9, 'title': 'WALL-E', 'studio': 'BV', 'bo_year': 2008}, {'bo_year_rank': 10, 'title': 'The Chronicles of Narnia Prince Caspian', 'studio': 'BV', 'bo_year': 2008}, {'bo_year_rank': 1, 'title': 'Avatar', 'studio': 'Fox', 'bo_year': 2009}, {'bo_year_rank': 2, 'title': 'Harry Potter and the Half-Blood Prince', 'studio': 'WB', 'bo_year': 2009}, {'bo_year_rank': 3, 'title': 'Ice Age Dawn of the Dinosaurs', 'studio': 'Fox', 'bo_year': 2009}, {'bo_year_rank': 4, 'title': 'Transformers Revenge of the Fallen', 'studio': 'PDW', 'bo_year': 2009}, {'bo_year_rank': 5, 'title': '2012', 'studio': 'Sony', 'bo_year': 2009}, {'bo_year_rank': 6, 'title': 'Up', 'studio': 'BV', 'bo_year': 2009}, {'bo_year_rank': 7, 'title': 'The Twilight Saga New Moon', 'studio': 'Sum.', 'bo_year': 2009}, {'bo_year_rank': 8, 'title': 'Sherlock Holmes', 'studio': 'WB', 'bo_year': 2009}, {'bo_year_rank': 9, 'title': 'Angels  Demons', 'studio': 'Sony', 'bo_year': 2009}, {'bo_year_rank': 10, 'title': 'The Hangover', 'studio': 'WB', 'bo_year': 2009}, {'bo_year_rank': 1, 'title': 'Toy Story 3', 'studio': 'BV', 'bo_year': 2010}, {'bo_year_rank': 2, 'title': 'Alice in Wonderland 2010', 'studio': 'BV', 'bo_year': 2010}, {'bo_year_rank': 3, 'title': 'Harry Potter and the Deathly Hallows Part 1', 'studio': 'WB', 'bo_year': 2010}, {'bo_year_rank': 4, 'title': 'Inception', 'studio': 'WB', 'bo_year': 2010}, {'bo_year_rank': 5, 'title': 'Shrek Forever After', 'studio': 'PDW', 'bo_year': 2010}, {'bo_year_rank': 6, 'title': 'The Twilight Saga Eclipse', 'studio': 'Sum.', 'bo_year': 2010}, {'bo_year_rank': 7, 'title': 'Iron Man 2', 'studio': 'Par.', 'bo_year': 2010}, {'bo_year_rank': 8, 'title': 'Tangled', 'studio': 'BV', 'bo_year': 2010}, {'bo_year_rank': 9, 'title': 'Despicable Me', 'studio': 'Uni.', 'bo_year': 2010}, {'bo_year_rank': 10, 'title': 'How to Train Your Dragon', 'studio': 'PDW', 'bo_year': 2010}, {'bo_year_rank': 1, 'title': 'Harry Potter and the Deathly Hallows Part 2', 'studio': 'WB', 'bo_year': 2011}, {'bo_year_rank': 2, 'title': 'Transformers Dark of the Moon', 'studio': 'PDW', 'bo_year': 2011}, {'bo_year_rank': 3, 'title': 'Pirates of the Caribbean On Stranger Tides', 'studio': 'BV', 'bo_year': 2011}, {'bo_year_rank': 4, 'title': 'The Twilight Saga Breaking Dawn Part 1', 'studio': 'Sum.', 'bo_year': 2011}, {'bo_year_rank': 5, 'title': 'Mission Impossible - Ghost Protocol', 'studio': 'Par.', 'bo_year': 2011}, {'bo_year_rank': 6, 'title': 'Kung Fu Panda 2', 'studio': 'PDW', 'bo_year': 2011}, {'bo_year_rank': 7, 'title': 'Fast Five', 'studio': 'Uni.', 'bo_year': 2011}, {'bo_year_rank': 8, 'title': 'The Hangover Part II', 'studio': 'WB', 'bo_year': 2011}, {'bo_year_rank': 9, 'title': 'The Smurfs', 'studio': 'Sony', 'bo_year': 2011}, {'bo_year_rank': 10, 'title': 'Cars 2', 'studio': 'BV', 'bo_year': 2011}, {'bo_year_rank': 1, 'title': 'Marvels The Avengers', 'studio': 'BV', 'bo_year': 2012}, {'bo_year_rank': 2, 'title': 'Skyfall', 'studio': 'Sony', 'bo_year': 2012}, {'bo_year_rank': 3, 'title': 'The Dark Knight Rises', 'studio': 'WB', 'bo_year': 2012}, {'bo_year_rank': 4, 'title': 'The Hobbit An Unexpected Journey', 'studio': 'WB NL', 'bo_year': 2012}, {'bo_year_rank': 5, 'title': 'Ice Age Continental Drift', 'studio': 'Fox', 'bo_year': 2012}, {'bo_year_rank': 6, 'title': ...

# %%
def movie_scraper():
    years=[str(a) for a in range(2008,2019)]
    df_list=[]
    for year in years:
        r=rq.get('https://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=%s&p=.htm' % year)
        print('Box Office data for %s scraped' % year)
        p=BeautifulSoup(r.text,'html.parser')

        ### Look for the table ### 
        b=p.find_all('table')

        ### Usually the fourth table object on page ### 
        tb=b[3].find_all('td')

        ## Each data field is found in a <td> element in the fourth table. Store all data in a list ## 
        data=[]
        for i in tb:
            if i.find('a')!=None:
                data.append(i.find('a').contents[0])
            elif i.find('font')!=None:
                 data.append(i.find('font').contents[0])
            elif i.find('b')!=None:
                data.append(i.find('b').contents[0])

        ### Still a <b> tag left for <font> tags ## 
        data=[a.contents[0] if type(a)!=bs4.element.NavigableString else a for a in data]

        ### Strip special characters ### 
        data=[re.sub('[^A-Za-z0-9-. ]+', '', a) for a in data]

        ### Fill NaNs ### 
        data=[np.nan if a =='na' else a for a in data]

        ### Define the feature names ###
        columns=['bo_year_rank','title','studio','worldwide-gross','domestic-gross','domestic-pct','overseas-gross','overseas-pct']

        ### First 6 elements are column headers # 
        to_df=data[6:]

        ### Escape clause in case the layout changes from year to year ### 
        if len(to_df)%len(columns) != 0:
            print('Possible table misalignment in table for year %s' % year)
            break 

        ### Convert to pandas dataframe ### 

        nrow=int(len(to_df)/len(columns))
        df=pd.DataFrame(np.array(to_df).reshape(nrow,8),columns=columns)
        df['bo_year']=int(year)
        df_list.append(df)

    dirtymovies_df=pd.concat(df_list)
    
    dirtymovies_df = dirtymovies_df.iloc[: , [0, 1, 2, 8]]
    dirtymovies_df["bo_year_rank"] = dirtymovies_df["bo_year_rank"].apply(int)
    movies_df = dirtymovies_df.loc[dirtymovies_df["bo_year_rank"] <=10,:]
    
    Moviedictionary = movies_df.to_dict(orient='records') 
    
    return (Moviedictionary)

# %%
# Out:
#   bo_year_rank                                      title studio  \
# 0            1                           Avengers Endgame     BV
# 1            2                            Captain Marvel      BV
# 2            3                        The Wandering Earth    CMC
# 3            4  How to Train Your Dragon The Hidden World   Uni.
# 4            5                         Alita Battle Angel    Fox
# 5            6                                     Shazam  WB NL
# 6            7                                 Dumbo 2019     BV
# 7            8                                         Us   Uni.
# 8            9                                      Glass   Uni.
# 9           10           The LEGO Movie 2 The Second Part     WB
#
#    worldwide-gross  domestic-gross  overseas-gross  bo_year
# 0     1.342700e+09     394000000.0     948700000.0     2019
# 1     1.111400e+09     414500000.0     696800000.0     2019
# 2     6.998000e+08       5900000.0     693900000.0     2019
# 3     5.164000e+08     159700000.0     356700000.0     2019
# 4     4.044000e+08      85700000.0     318700000.0     2019
# 5     3.462000e+08     131500000.0     214700000.0     2019
# 6     3.287000e+08     107500000.0     221200000.0     2019
# 7     2.496000e+08     173000000.0      76600000.0     2019
# 8     2.470000e+08     111000000.0     135900000.0     2019
# 9     1.905000e+08     105700000.0      84800000.0     2019

# %% [markdown]
#   if x is >= 1000000000 then convert to "1.xx billion"  to make more readable we are going from float to string
#   else convert to xxxmillion
#
#   Next steps for arjun figure out function above then put finished dataframe into mongodbcollection
